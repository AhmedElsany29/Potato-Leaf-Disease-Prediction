# %%
import numpy as np 
import pandas as pd 


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/potato-leaf-disease-dataset/Potato/Valid/Potato___healthy/Potato_healthy-66-_0_305.jpg
# /kaggle/input/potato-leaf-disease-dataset/Potato/Valid/Potato___healthy/Potato_healthy-55-_0_178.jpg
# /kaggle/input/potato-leaf-disease-dataset/Potato/Valid/Potato___healthy/Potato_healthy-69-_0_9193.jpg
# /kaggle/input/potato-leaf-disease-dataset/Potato/Valid/Potato___healthy/Potato_healthy-73-_0_9057.jpg
# /kaggle/input/potato-leaf-disease-dataset/Potato/Valid/Potato___healthy/Potato_healthy-72-_0_5665.jpg
# /kaggle/input/potato-leaf-disease-dataset/Potato/Valid/Potato___healthy/Potato_healthy-57-_0_3897.jpg
# /kaggle/input/potato-leaf-disease-dataset/Potato/Valid/Potato___healthy/Potato_healthy-68-_0_3217.jpg
# /kaggle/input/potato-leaf-disease-dataset/Potato/Valid/Potato___healthy/Potato_healthy-71-_0_5097.jpg
# /kaggle/input/potato-leaf-disease-dataset/Potato/Valid/Potato___healthy/Potato_healthy-70-_0_8201.jpg
# ...

# %%
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import glob
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from tensorflow.keras.utils import to_categorical

# %%
BATCH_SIZE = 32
train_datagen= ImageDataGenerator(
        rescale=1./255,
        rotation_range=30,
        shear_range=0.2,
        zoom_range=0.2,
        width_shift_range=0.05,
        height_shift_range=0.05,
        horizontal_flip=True,
        fill_mode='nearest')

validation_datagen= ImageDataGenerator(rescale=1./255)

test_datagen= ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        directory= '../input/potato-leaf-disease-dataset/Potato/Train',
        target_size= (256,256), # all images will be resized to 64*64
        batch_size= BATCH_SIZE,
        class_mode= 'categorical',
        color_mode="rgb")

validation_generator= validation_datagen.flow_from_directory(
            directory= '../input/potato-leaf-disease-dataset/Potato/Valid',
            target_size= (256,256),
            batch_size= BATCH_SIZE,
            class_mode= 'categorical',
            color_mode="rgb")

test_generator = test_datagen.flow_from_directory(
        directory='../input/potato-leaf-disease-dataset/Potato/Test',
        target_size = (256, 256),
        batch_size = BATCH_SIZE,
        class_mode = 'categorical',
        color_mode = "rgb")
# Out:
# Found 900 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.models import Sequential
from keras.layers import Dense, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator

base_model = VGG19(input_shape=(256, 256, 3), include_top=False)
base_model.trainable = False

model = Sequential()

model.add(base_model)

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='tanh'))
model.add(Dense(16, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(3, activation='softmax'))

model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])

callback = keras.callbacks.EarlyStopping(monitor='val_loss',patience =2 )

model.fit(train_generator, epochs=5, validation_data=validation_generator, callbacks=callback)
# Out:
# Epoch 1/5
# 29/29 [==============================] - 510s 18s/step - loss: 1.0658 - accuracy: 0.4422 - val_loss: 1.0147 - val_accuracy: 0.5600
# Epoch 2/5
# 29/29 [==============================] - 507s 18s/step - loss: 0.9650 - accuracy: 0.5933 - val_loss: 0.8678 - val_accuracy: 0.6200
# Epoch 3/5
# 29/29 [==============================] - 511s 18s/step - loss: 0.8612 - accuracy: 0.5933 - val_loss: 0.7968 - val_accuracy: 0.6033
# Epoch 4/5
# 29/29 [==============================] - 514s 18s/step - loss: 0.7645 - accuracy: 0.6111 - val_loss: 0.7332 - val_accuracy: 0.6233
# Epoch 5/5
# 29/29 [==============================] - 505s 18s/step - loss: 0.7243 - accuracy: 0.6000 - val_loss: 0.7098 - val_accuracy: 0.5967

# %%
from tensorflow.keras.applications import ResNet50
base_model = ResNet50(input_shape=(256, 256, 3), include_top=False)
base_model.trainable = False

model = Sequential()

model.add(base_model)

model.add(Flatten())

model.add(Dense(3, activation='softmax'))

ad = keras.optimizers.Adam(learning_rate = 0.0005)

model.compile(optimizer = ad , loss = 'categorical_crossentropy', metrics = ['accuracy'])

model.fit(train_generator, epochs=5, validation_data=validation_generator)
# Out:
# Epoch 1/5
# 29/29 [==============================] - 124s 4s/step - loss: 2.5158 - accuracy: 0.4300 - val_loss: 0.8250 - val_accuracy: 0.5700
# Epoch 2/5
# 29/29 [==============================] - 118s 4s/step - loss: 1.0133 - accuracy: 0.5344 - val_loss: 0.8380 - val_accuracy: 0.5767
# Epoch 3/5
# 29/29 [==============================] - 118s 4s/step - loss: 0.9462 - accuracy: 0.5767 - val_loss: 1.0244 - val_accuracy: 0.6367
# Epoch 4/5
# 29/29 [==============================] - 118s 4s/step - loss: 0.8395 - accuracy: 0.6433 - val_loss: 0.6364 - val_accuracy: 0.7200
# Epoch 5/5
# 29/29 [==============================] - 118s 4s/step - loss: 1.0753 - accuracy: 0.5478 - val_loss: 1.9779 - val_accuracy: 0.5933

# %%
from tensorflow.keras.applications import InceptionResNetV2 ,InceptionV3

base_model = InceptionV3(input_shape = (256, 256, 3), include_top=False)

model = Sequential()

model.add(base_model)

model.add(Flatten())

model.add(Dense(3, activation='softmax'))

model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy', metrics = ['accuracy'])

model.fit(train_generator, epochs=5, validation_data=validation_generator)
# Out:
# Epoch 1/5
# 29/29 [==============================] - 257s 9s/step - loss: 1.4932 - accuracy: 0.8189 - val_loss: 1328.2551 - val_accuracy: 0.3333
# Epoch 2/5
# 29/29 [==============================] - 247s 9s/step - loss: 0.8145 - accuracy: 0.9233 - val_loss: 497471.7188 - val_accuracy: 0.3333
# Epoch 3/5
# 29/29 [==============================] - 245s 8s/step - loss: 2.3876 - accuracy: 0.7978 - val_loss: 1104733312.0000 - val_accuracy: 0.3067
# Epoch 4/5
# 29/29 [==============================] - 247s 8s/step - loss: 1.7609 - accuracy: 0.8956 - val_loss: 1335841.8750 - val_accuracy: 0.3333
# Epoch 5/5
# 29/29 [==============================] - 249s 9s/step - loss: 0.4200 - accuracy: 0.9167 - val_loss: 577258.5000 - val_accuracy: 0.3333

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.models import Sequential
from keras.layers import Dense, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionResNetV2 ,InceptionV3

base_model = InceptionResNetV2(input_shape=(256, 256, 3), include_top=False)

base_model.trainable = False

model = Sequential()

model.add(base_model)

model.add(Flatten())

model.add(Dense(3, activation='softmax'))

model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy', metrics = ['accuracy'])

model.fit(train_generator, epochs=5, validation_data=validation_generator)
# Out:
# ...
# 219070464/219055592 [==============================] - 2s 0us/step
# Epoch 1/5
# 29/29 [==============================] - 207s 7s/step - loss: 3.3205 - accuracy: 0.6622 - val_loss: 1.4111 - val_accuracy: 0.8000
# Epoch 2/5
# 29/29 [==============================] - 190s 7s/step - loss: 0.7879 - accuracy: 0.8600 - val_loss: 0.3423 - val_accuracy: 0.9033
# Epoch 3/5
# 29/29 [==============================] - 191s 7s/step - loss: 0.4691 - accuracy: 0.9144 - val_loss: 1.2821 - val_accuracy: 0.7800
# Epoch 4/5
# 29/29 [==============================] - 191s 7s/step - loss: 0.1936 - accuracy: 0.9422 - val_loss: 0.3210 - val_accuracy: 0.9067
# Epoch 5/5
# 29/29 [==============================] - 191s 7s/step - loss: 0.2480 - accuracy: 0.9467 - val_loss: 0.7485 - val_accuracy: 0.8400

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.models import Sequential
from keras.layers import Dense, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionResNetV2 ,InceptionV3 ,Xception

base_model = Xception(input_shape=(256, 256, 3), include_top=False)

base_model.trainable = False

model = Sequential()

model.add(base_model)

# model/add(dense)

model.add(Flatten())

# model/add(dense)

model.add(Dense(3, activation='softmax'))

model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy', metrics = ['accuracy'])

model.fit(train_generator, epochs=5, validation_data=validation_generator)
# Out:
# ...
# 83697664/83683744 [==============================] - 1s 0us/step
# Epoch 1/5
# 29/29 [==============================] - 133s 5s/step - loss: 2.6813 - accuracy: 0.7256 - val_loss: 1.3725 - val_accuracy: 0.8733
# Epoch 2/5
# 29/29 [==============================] - 129s 4s/step - loss: 0.6446 - accuracy: 0.9256 - val_loss: 0.9029 - val_accuracy: 0.8900
# Epoch 3/5
# 29/29 [==============================] - 130s 4s/step - loss: 0.2783 - accuracy: 0.9511 - val_loss: 0.4060 - val_accuracy: 0.9500
# Epoch 4/5
# 29/29 [==============================] - 130s 4s/step - loss: 0.2479 - accuracy: 0.9589 - val_loss: 0.3175 - val_accuracy: 0.9600
# Epoch 5/5
# 29/29 [==============================] - 130s 5s/step - loss: 0.1452 - accuracy: 0.9644 - val_loss: 0.4069 - val_accuracy: 0.9433

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.models import Sequential
from keras.layers import Dense, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionResNetV2,InceptionV3,Xception,MobileNet

base_model = MobileNet(input_shape=(256, 256, 3), include_top=False)

base_model.trainable = False

model = Sequential()

model.add(base_model)

# model/add(dense)

model.add(Flatten())

# model/add(dense)

model.add(Dense(3, activation='softmax'))

model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy', metrics = ['accuracy'])

model.fit(train_generator, epochs=5, validation_data=validation_generator)
# Out:
# ...
# 17235968/17225924 [==============================] - 0s 0us/step
# Epoch 1/5
# 29/29 [==============================] - 36s 1s/step - loss: 2.2680 - accuracy: 0.7889 - val_loss: 0.5035 - val_accuracy: 0.9600
# Epoch 2/5
# 29/29 [==============================] - 34s 1s/step - loss: 0.3955 - accuracy: 0.9533 - val_loss: 0.8143 - val_accuracy: 0.9067
# Epoch 3/5
# 29/29 [==============================] - 34s 1s/step - loss: 0.2178 - accuracy: 0.9733 - val_loss: 0.2366 - val_accuracy: 0.9533
# Epoch 4/5
# 29/29 [==============================] - 33s 1s/step - loss: 0.0789 - accuracy: 0.9878 - val_loss: 0.2746 - val_accuracy: 0.9700
# Epoch 5/5
# 29/29 [==============================] - 34s 1s/step - loss: 0.0504 - accuracy: 0.9900 - val_loss: 0.2032 - val_accuracy: 0.9833

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.models import Sequential
from keras.layers import Dense, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionResNetV2,InceptionV3,Xception,MobileNet ,DenseNet121

base_model = DenseNet121(input_shape=(256, 256, 3), include_top=False)

base_model.trainable = False

model = Sequential()

model.add(base_model)

# model/add(dense)

model.add(Flatten())

# model/add(dense)

model.add(Dense(3, activation='softmax'))

model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy', metrics = ['accuracy'])

model.fit(train_generator, epochs=5, validation_data=validation_generator)
# Out:
# ...
# 29097984/29084464 [==============================] - 0s 0us/step
# Epoch 1/5
# 29/29 [==============================] - 110s 4s/step - loss: 2.7559 - accuracy: 0.7422 - val_loss: 0.8729 - val_accuracy: 0.8633
# Epoch 2/5
# 29/29 [==============================] - 100s 3s/step - loss: 0.4284 - accuracy: 0.9367 - val_loss: 0.8999 - val_accuracy: 0.8767
# Epoch 3/5
# 29/29 [==============================] - 99s 3s/step - loss: 0.1178 - accuracy: 0.9667 - val_loss: 0.3700 - val_accuracy: 0.9100
# Epoch 4/5
# 29/29 [==============================] - 98s 3s/step - loss: 0.0779 - accuracy: 0.9822 - val_loss: 0.2502 - val_accuracy: 0.9400
# Epoch 5/5
# 29/29 [==============================] - 98s 3s/step - loss: 0.0298 - accuracy: 0.9911 - val_loss: 0.1185 - val_accuracy: 0.9767

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.models import Sequential
from keras.layers import Dense, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionResNetV2,InceptionV3,Xception
from tensorflow.keras.applications import MobileNet ,DenseNet121 , EfficientNetB2

base_model = EfficientNetB2(input_shape=(256, 256, 3), include_top=False)

base_model.trainable = False

model = Sequential()

model.add(base_model)

# model/add(dense)

model.add(Flatten())

# model/add(dense)

model.add(Dense(3, activation='softmax'))

model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy', metrics = ['accuracy'])

model.fit(train_generator, epochs=5, validation_data=validation_generator)
# Out:
# ...
# 31801344/31790344 [==============================] - 0s 0us/step
# Epoch 1/5
# 29/29 [==============================] - 66s 2s/step - loss: 13.2244 - accuracy: 0.3567 - val_loss: 8.7976 - val_accuracy: 0.3333
# Epoch 2/5
# 29/29 [==============================] - 54s 2s/step - loss: 5.0809 - accuracy: 0.3211 - val_loss: 3.4612 - val_accuracy: 0.3333
# Epoch 3/5
# 29/29 [==============================] - 54s 2s/step - loss: 2.7759 - accuracy: 0.3300 - val_loss: 2.7070 - val_accuracy: 0.3333
# Epoch 4/5
# 29/29 [==============================] - 53s 2s/step - loss: 2.4888 - accuracy: 0.3267 - val_loss: 4.8302 - val_accuracy: 0.3333
# Epoch 5/5
# 29/29 [==============================] - 54s 2s/step - loss: 5.3354 - accuracy: 0.3289 - val_loss: 4.4319 - val_accuracy: 0.3333
